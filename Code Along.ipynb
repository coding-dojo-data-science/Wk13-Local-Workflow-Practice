# %% [markdown]
# # Code along

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading file from Data folder

# %%
df = pd.read_csv('Data/data_science_salary_2021.csv')

# %%
df
# Out:
#      index                                          Job Title  \
# 0        0                                     Data Scientist
# 1        1                          Healthcare Data Scientist
# 2        2                                     Data Scientist
# 3        3                                     Data Scientist
# 4        4                                     Data Scientist
# ..     ...                                                ...
# 737    950           Sr Scientist, Immuno-Oncology - Oncology
# 738    951                               Senior Data Engineer
# 739    952  Project Scientist - Auton Lab, Robotics Institute
# 740    953                               Data Science Manager
# 741    955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ...

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   index               742 non-null    int64
#  1   Job Title           742 non-null    object
#  2   Salary Estimate     742 non-null    object
#  3   Job Description     742 non-null    object
#  4   Rating              742 non-null    float64
#  5   Company Name        742 non-null    object
#  6   Location            742 non-null    object
#  7   Headquarters        742 non-null    object
#  8   Size                742 non-null    object
#  9   Founded             742 non-null    int64
#  10  Type of ownership   742 non-null    object
#  11  Industry            742 non-null    object
#  12  Sector              742 non-null    object
#  13  Revenue             742 non-null    object
#  14  Competitors         742 non-null    object
# ...

# %% [markdown]
# ## What is the mean  'Avg Salary(K)' according to “job_title_sim”?

# %%
df['Avg Salary(K)']
# Out:
# 0       72.0
# 1       87.5
# 2       85.0
# 3       76.5
# 4      114.5
#        ...
# 737     84.5
# 738    102.5
# 739     73.5
# 740    127.5
# 741     93.5
# Name: Avg Salary(K), Length: 742, dtype: float64

# %%
ax = sns.barplot(data=df, x='job_title_sim',y='Avg Salary(K)')
ax.set_xticklabels(ax.get_xticklabels(),rotation=45,ha = 'right');
plt.savefig('barplot.png',pad_inches = 1, bbox_inches = 'tight')
#plt.tick_params(labelrotation =45)

# %% [markdown]
# ### Save the plot using savefig()

# %%
#plt.savefig('barplot.png',pad_inches = 1, bbox_inches = 'tight')

# %% [markdown]
# ![png](barplot.png)

# %% [markdown]
# ## Which job title uses Python most according to “job_title_sim”?

# %%
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [14,6]

# %%
#df.groupby("Python")["job_title_sim"].value_counts().unstack(0).plot.bar()

# %% [markdown]
# ### Save the plot as barplot_python using savefig()

# %%
ax = sns.countplot(data=df, x='job_title_sim',hue='Python')
ax.set_xticklabels(ax.get_xticklabels(),rotation=90,ha = 'right');

# %%
plt.savefig('Python_cnt.png',pad_inches = 1, bbox_inches = 'tight')
